# %% [markdown]
# # HTML and CSS - Parsing Markup
#
# ## HTML
#
# HTML is the semantic structure of a website and is composed of elements denoted by specific tags. A tag looks like this:
#
# ```html
# <tagname>tag content</tagname>
# ```
#
# Tags usually have opening and closing tags, with the `/` being used to indicate the closing tag. This marks the end of the tag.
#
# ```html
# <p>I'm a paragraph</p>
# ```
#
# Elements can also be self closing - the image element technically does not need a closing tag
#
# ```html
# <img src="https://some.url/coolimage.jpg">
# ```
#
# There are many different types of tags, and they all have different semantic meaning ([you can read more here](https://www.hongkiat.com/blog/html-5-semantics/)). However, their implementation varies and there is no universally used standard when building websites. Below are some widely used versions:
#
# * `p`: paragraph of text
# * `a`: a link
# * `ul`: an unordered (bulleted) list
# * `li`: a list item
# * `strong`: important text (typically displays bold)
# * `h1` through `h6`: heading levels 1 through 6
# * `div`: a widely used tag used to signify a division or section of content
#
# It's worth noting that of all these tags, the `div` tag is a "pure" container and does not inherently represent anything semantically. Typically it is used in order to apply styling with CSS, which we will cover later.
#
# ## Attributes
#
# Attributes are extra bits of information that appear inside the opening tag - their values sit inside quotation marks. These values configure the elements or adjust their behavior in various ways.
#
# ```html
# <tagname attributename="value">tag content</tagname>
# ```
#
# Some attributes are specific to certain tags, while others can be applied to any tag. We will look at the two most important such attributes for our purposes - `id` and `class`.
#
# The `id` attribute gives a **unique** id to a tag. This tag is traditionally used for accessing elements with javascript. There can only be **one** tag with any given `id`. We'll soon see why this level of specificity is useful.
#
# The `class` attribute is primarily used for styling elements. Multiple tags of different type can share the same class name.
#
# ```html
# <ul id="the_list">
#     <li class="list_element">The data we want</li>
#     <li class="list_element">The data we want</li>
#     <li class="list_element">The data we want</li>
# </ul>
# ```
#
# Some attributes are specific to certain tags. This includes the image element's `src` tag which is a link to the image URL
#
# ```html
# <img src="https://some.url/coolimage.jpg">
# ```
#
# This also includes the `a` tag's `href` link, which indicates where the browser should navigate to when interacted with.
#
# ```html
# <a href="https://mycoollink.com">check out my cool link</a>
# ```
#
# ## Webpage Structure
#
# Most webpage documents contain the following tags:
#
# * `html`: This surrounds the entire document
# * `head`: Contains the title and other information such as links to style sheets and javascript. It does not render any visible content.
# * `title`: The title of the page shown in the browser tab
# * `body`: Contains all visible elements on the website
#
# An example HTML document:
#
# ```html
# <html>
#     <head>
#         <title>Some website with data</title>
#     </head>
#     <body>
#         <h1>Welcome to our website</h1>
#         <p>Please do not scrape this well formatted data</p>
#
#         <ul>
#             <li>beautiful</li>
#             <li>delicious</li>
#             <li>data</li>
#         </ul>
#     </body>
# </html>
# ```
#
# HTML Elements are nested within each other, indicating heirarchy. The indentations are optional but help to visually indicate the inherent heirarchy.
#
# ## Using the Chrome inspector
#
# We will use the Chrome developer tools to inspect our web pages, but Firefox, Safari, and Edge also have developer tools you can use. Chrome and Firefox are generally well regarded.
#
# ## Isolating elements with query selector
#
# CSS is applied to html elements using query selectors - we will use the same to select HTML elements in python.
# [Read more here](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors)

# %% [markdown]
# ## Using Python to Scrape Websites
#
# Covering the basics of web scraping with Python
#
# You can use Python's standard library to scrape the web and there are also a number of other packages available for scraping in Python and other languages, but we will use `requests-html` due to its ease of use.
#
# First we need to install `requests_html`
#
# ```console
# $ pip3 install requests-html
# ```
#
# The basic workflow for scraping is to download HTML from a url, and then parse the resulting HTML using query selectors.

# %%
from requests_html import HTMLSession

session = HTMLSession()

# Then we use session.get to get the contents of the url
response = session.get('https://newyork.craigslist.org/d/free-stuff/search/zip')

# %%
# First we get all the URLs for all of the listings
# Looking at the page, we can see that the links are
# a tags with "resulte-image" class applied. By using this
# query selector we get a list of all the links

link_tags = response.html.find("a.result-image")

# %%
# Then we can loop through all the links and grab
# the href attribute from the a tag

links = []

for link in link_tags:
    links.append(link.attrs.get('href'))

# %%
# We can use the pandas library to keep track of our data

import pandas as pd

clist_df = pd.DataFrame(columns=['id', 'images', 'title', 'description'])
clist_df
# Out:
# Empty DataFrame
# Columns: [id, images, title, description]
# Index: []

# %%
# Next we loop through our links and grab the HTML for each link

for link in links:
    response = session.get(link)
    
    # Web scraping often breaks due to small errors, so it can
    # be easiest to wrap our code in a try block and grab the errors
    try: 
    
        page_id = link.split('/')[-1].replace('.html', '')

        images = [img.attrs.get('src') for img in response.html.find('.slide img')]

        title = response.html.find('#titletextonly', first=True).text

        description = response.html.find("#postingbody", first=True).text

        clist_df = clist_df.append({'id': page_id,
            'images': images,
            'title': title,
            'description': description}, ignore_index=True)

    except Exception as e:
        # Print the error
        print(e)
        # and print the associated link
        print('failed on ' + link)
# Out:
# 'NoneType' object has no attribute 'text'
# failed on https://newyork.craigslist.org/mnh/zip/d/new-york-counter-top-oven/6989340916.html
# 'NoneType' object has no attribute 'text'
# failed on https://newyork.craigslist.org/brk/zip/d/brooklyn-closet-ikea/6989188399.html

# %%
# We can see we got all the data below! 
# Unfortunately only the first image of the slideshow renders
clist_df
# Out:
#              id                                             images  \
# 0    6989347730  [https://images.craigslist.org/00y0y_dzCOy8akK...
# 1    6989344686  [https://images.craigslist.org/00u0u_3Bxy7UzgV...
# 2    6988069432  [https://images.craigslist.org/00N0N_YRPBBlU5o...
# 3    6988070585  [https://images.craigslist.org/00C0C_5VNAb0tss...
# 4    6988074993  [https://images.craigslist.org/00D0D_JGwaEemNM...
# ..          ...                                                ...
# 113  6987426885  [https://images.craigslist.org/00i0i_kWJStA00L...
# 114  6989121965  [https://images.craigslist.org/00606_8BBJRIePd...
# 115  6980930696  [https://images.craigslist.org/00R0R_3JSNlmFVb...
# 116  6989118778  [https://images.craigslist.org/01313_7k1wogZht...
# 117  6989118015  [https://images.craigslist.org/00G0G_bzTZwFt6Z...
#
#                                           title  \
# 0        Free IKEA BOOKSHELF and Wooden Dresser
# 1                                     Baby Food
# 2                             Two free CD cases
# 3        Free DVD about managing genital herpes
# 4         8 Sony DVD+R new blank cds with cases
# ..                                          ...
# 113              Large Rubbermaid full of Goods
# 114                                 Toilet rack
# 115                    2 Couches good condition
# 116                              Need gone asap
# 117  Records, books, DVD’s , Cds, Clothes. Curb
#
#                                            description
# 0    QR Code Link to This Post\nIKEA shelf and Wood...
# 1    QR Code Link to This Post\nI have new and unop...
# 2      QR Code Link to This Post\nNo discs, just cases
# 3           QR Code Link to This Post\nCome and get it
# 4    QR Code Link to This Post\nBrand new\nCome and...
# ..                                                 ...
# 113  QR Code Link to This Post\nLarge Rubbermaid fu...
# 114  QR Code Link to This Post\nFits over a toilet ...
# 115  QR Code Link to This Post\n2 Couches good cond...
# 116   QR Code Link to This Post\nNeed these gone asap.
# 117  QR Code Link to This Post\nAn ever growing mov...
#
# [118 rows x 4 columns]

# %%
# We can use urllib to download the image urls
# into a folder names "scraped_images"

import urllib.request

for index, row in clist_df.iterrows():

    for url in row['images']:
        print(url)
        file_name = url.split('/')[-1]
        print(file_name)
        urllib.request.urlretrieve(url, 'scraped_images/' + file_name)
# Out:
# https://images.craigslist.org/00y0y_dzCOy8akKXS_600x450.jpg
# 00y0y_dzCOy8akKXS_600x450.jpg
# https://images.craigslist.org/00u0u_3Bxy7UzgVEr_600x450.jpg
# 00u0u_3Bxy7UzgVEr_600x450.jpg
# https://images.craigslist.org/00N0N_YRPBBlU5ox_600x450.jpg
# 00N0N_YRPBBlU5ox_600x450.jpg
# https://images.craigslist.org/00C0C_5VNAb0tss7m_600x450.jpg
# 00C0C_5VNAb0tss7m_600x450.jpg
# https://images.craigslist.org/00D0D_JGwaEemNMX_600x450.jpg
# 00D0D_JGwaEemNMX_600x450.jpg
# https://images.craigslist.org/00Z0Z_50HBOTnAMAS_600x450.jpg
# 00Z0Z_50HBOTnAMAS_600x450.jpg
# https://images.craigslist.org/00A0A_5dlH6mCdHkU_600x450.jpg
# 00A0A_5dlH6mCdHkU_600x450.jpg
# https://images.craigslist.org/00Q0Q_cmr2VjIaJSx_600x450.jpg
# 00Q0Q_cmr2VjIaJSx_600x450.jpg
# https://images.craigslist.org/01616_3RD8ZSKwPsf_600x450.jpg
# 01616_3RD8ZSKwPsf_600x450.jpg
# https://images.craigslist.org/00Q0Q_fNnY30Cndfj_600x450.jpg
# 00Q0Q_fNnY30Cndfj_600x450.jpg
# https://images.craigslist.org/00808_bJ9qnQCtLrN_600x450.jpg
# 00808_bJ9qnQCtLrN_600x450.jpg
# https://images.craigslist.org/00000_yJRTiiWPpN_600x450.jpg
# 00000_yJRTiiWPpN_600x450.jpg
# https://images.craigslist.org/00O0O_2oZ1rsBfKhf_600x450.jpg
# 00O0O_2oZ1rsBfKhf_600x450.jpg
# https://images.craigslist.org/01313_d8Sx1T8fzpu_600x450.jpg
# 01313_d8Sx1T8fzpu_600x450.jpg
# https://images.craigslist.org/00606_4R7Fbaq53wx_600x450.jpg
# 00606_4R7Fbaq53wx_600x450.jpg
# https://images.craigslist.org/00I0I_8hN1knS4yiH_600x450.jpg
# 00I0I_8hN1knS4yiH_600x450.jpg
# https://images.craigslist.org/01212_2e41MQjWtaG_600x450.jpg
# 01212_2e41MQjWtaG_600x450.jpg
# https://images.craigslist.org/00h0h_gu9HpAEFGJN_600x450.jpg
# 00h0h_gu9HpAEFGJN_600x450.jpg
# https://images.craigslist.org/00J0J_95cndBZ2DOp_600x450.jpg
# 00J0J_95cndBZ2DOp_600x450.jpg
# https://images.craigslist.org/01414_5od4fIitdlX_600x450.jpg
# 01414_5od4fIitdlX_600x450.jpg
# https://images.craigslist.org/00d0d_6jzBwjIqWD8_600x450.jpg
# 00d0d_6jzBwjIqWD8_600x450.jpg
# https://images.craigslist.org/00z0z_jhMUSZ5wXuT_600x450.jpg
# 00z0z_jhMUSZ5wXuT_600x450.jpg
# https://images.craigslist.org/00D0D_5o3RUzfEnfB_600x450.jpg
# 00D0D_5o3RUzfEnfB_600x450.jpg
# https://images.craigslist.org/00a0a_ev2iNewCbZp_600x450.jpg
# 00a0a_ev2iNewCbZp_600x450.jpg
# https://images.craigslist.org/00s0s_5SUR8GvVY8h_600x450.jpg
# 00s0s_5SUR8GvVY8h_600x450.jpg
# https://images.craigslist.org/00I0I_iooQKRgzD8n_600x450.jpg
# 00I0I_iooQKRgzD8n_600x450.jpg
# https://images.craigslist.org/00H0H_3ZMwNQTbbYl_600x450.jpg
# 00H0H_3ZMwNQTbbYl_600x450.jpg
# https://images.craigslist.org/00e0e_tUIcK34TTl_600x450.jpg
# 00e0e_tUIcK34TTl_600x450.jpg
# https://images.craigslist.org/00606_3BS0JjgSYAu_600x450.jpg
# 00606_3BS0JjgSYAu_600x450.jpg
# https://images.craigslist.org/00b0b_1oXItyVb8tg_600x450.jpg
# 00b0b_1oXItyVb8tg_600x450.jpg
# https://images.craigslist.org/00K0K_zD64TU4iSx_600x450.jpg
# 00K0K_zD64TU4iSx_600x450.jpg
# https://images.craigslist.org/00M0M_l73fa813mcM_600x450.jpg
# 00M0M_l73fa813mcM_600x450.jpg
# https://images.craigslist.org/00c0c_atIpGD6STco_600x450.jpg
# 00c0c_atIpGD6STco_600x450.jpg
# https://images.craigslist.org/00h0h_4bnkrCCjmkK_600x450.jpg
# 00h0h_4bnkrCCjmkK_600x450.jpg
# https://images.craigslist.org/00f0f_efhK3036e9g_600x450.jpg
# 00f0f_efhK3036e9g_600x450.jpg
# https://images.craigslist.org/00s0s_5hTnIIoMo3d_600x450.jpg
# 00s0s_5hTnIIoMo3d_600x450.jpg
# https://images.craigslist.org/01111_5cI2zSqSSH9_600x450.jpg
# 01111_5cI2zSqSSH9_600x450.jpg
# https://images.craigslist.org/00l0l_bozqfQ3ABEJ_600x450.jpg
# 00l0l_bozqfQ3ABEJ_600x450.jpg
# https://images.craigslist.org/00M0M_7Bs4ieCpewc_600x450.jpg
# 00M0M_7Bs4ieCpewc_600x450.jpg
# https://images.craigslist.org/00J0J_1Lb3Kl91NtN_600x450.jpg
# 00J0J_1Lb3Kl91NtN_600x450.jpg
# https://images.craigslist.org/00H0H_2ny3o7lITdN_600x450.jpg
# 00H0H_2ny3o7lITdN_600x450.jpg
# https://images.craigslist.org/00t0t_iVUmTIuRBzF_600x450.jpg
# 00t0t_iVUmTIuRBzF_600x450.jpg
# https://images.craigslist.org/01212_lvV6ZZngU79_600x450.jpg
# 01212_lvV6ZZngU79_600x450.jpg
# https://images.craigslist.org/00w0w_59XdfPcmdqw_600x450.jpg
# 00w0w_59XdfPcmdqw_600x450.jpg
# https://images.craigslist.org/00L0L_4RJx6mWEkEQ_600x450.jpg
# 00L0L_4RJx6mWEkEQ_600x450.jpg
# https://images.craigslist.org/00c0c_9OiEQszNRyf_600x450.jpg
# 00c0c_9OiEQszNRyf_600x450.jpg
# https://images.craigslist.org/00101_6qjSWWFRv4W_600x450.jpg
# 00101_6qjSWWFRv4W_600x450.jpg
# https://images.craigslist.org/00I0I_5qJqMXPhtrf_600x450.jpg
# 00I0I_5qJqMXPhtrf_600x450.jpg
# https://images.craigslist.org/00404_lfG60a00AW4_600x450.jpg
# 00404_lfG60a00AW4_600x450.jpg
# https://images.craigslist.org/01313_iT3fZvNOmNa_600x450.jpg
# 01313_iT3fZvNOmNa_600x450.jpg
# https://images.craigslist.org/00x0x_g3iLGjKxB8q_600x450.jpg
# 00x0x_g3iLGjKxB8q_600x450.jpg
# https://images.craigslist.org/01313_a9BBlRgdfVr_600x450.jpg
# 01313_a9BBlRgdfVr_600x450.jpg
# https://images.craigslist.org/00o0o_bfqpRoGWXRs_600x450.jpg
# 00o0o_bfqpRoGWXRs_600x450.jpg
# https://images.craigslist.org/00f0f_7bXRL7MQA8X_600x450.jpg
# 00f0f_7bXRL7MQA8X_600x450.jpg
# https://images.craigslist.org/00606_hnnaVcLqIrS_600x450.jpg
# 00606_hnnaVcLqIrS_600x450.jpg
# https://images.craigslist.org/00i0i_83seZ3UNMKB_600x450.jpg
# 00i0i_83seZ3UNMKB_600x450.jpg
# https://images.craigslist.org/00L0L_f7GkTdnSzF0_600x450.jpg
# 00L0L_f7GkTdnSzF0_600x450.jpg
# https://images.craigslist.org/00t0t_e0t9gbyLYzR_600x450.jpg
# 00t0t_e0t9gbyLYzR_600x450.jpg
# https://images.craigslist.org/00f0f_bU9KbY7Wq1O_600x450.jpg
# 00f0f_bU9KbY7Wq1O_600x450.jpg
# https://images.craigslist.org/00z0z_dCpZIYNBgQ8_600x450.jpg
# 00z0z_dCpZIYNBgQ8_600x450.jpg
# https://images.craigslist.org/00o0o_dJ9N8tR79nb_600x450.jpg
# 00o0o_dJ9N8tR79nb_600x450.jpg
# https://images.craigslist.org/01414_3zbH8dndxjS_600x450.jpg
# 01414_3zbH8dndxjS_600x450.jpg
# https://images.craigslist.org/00r0r_7fJZmsuBKQm_600x450.jpg
# 00r0r_7fJZmsuBKQm_600x450.jpg
# https://images.craigslist.org/01313_1Hlas0HufQy_600x450.jpg
# 01313_1Hlas0HufQy_600x450.jpg
# https://images.craigslist.org/01616_l49NdDHWBgL_600x450.jpg
# 01616_l49NdDHWBgL_600x450.jpg
# https://images.craigslist.org/00w0w_14BLI9QkPv1_600x450.jpg
# 00w0w_14BLI9QkPv1_600x450.jpg
# https://images.craigslist.org/00j0j_8yvRVJrMDTR_600x450.jpg
# 00j0j_8yvRVJrMDTR_600x450.jpg
# https://images.craigslist.org/00505_1TyaATFGBiG_600x450.jpg
# 00505_1TyaATFGBiG_600x450.jpg
# https://images.craigslist.org/01414_2gA5z9vkW5n_600x450.jpg
# 01414_2gA5z9vkW5n_600x450.jpg
# https://images.craigslist.org/00H0H_KztkLokaZO_600x450.jpg
# 00H0H_KztkLokaZO_600x450.jpg
# https://images.craigslist.org/00Y0Y_3adEtwhFWUs_600x450.jpg
# 00Y0Y_3adEtwhFWUs_600x450.jpg
# https://images.craigslist.org/00I0I_4jkBgR3w5zw_600x450.jpg
# 00I0I_4jkBgR3w5zw_600x450.jpg
# https://images.craigslist.org/01717_4sgpsLfPqaH_600x450.jpg
# 01717_4sgpsLfPqaH_600x450.jpg
# https://images.craigslist.org/00Y0Y_3adEtwhFWUs_600x450.jpg
# 00Y0Y_3adEtwhFWUs_600x450.jpg
# https://images.craigslist.org/00Z0Z_aOuEpfqJSlv_600x450.jpg
# 00Z0Z_aOuEpfqJSlv_600x450.jpg
# https://images.craigslist.org/00K0K_4MNv2vKwmWb_600x450.jpg
# 00K0K_4MNv2vKwmWb_600x450.jpg
# https://images.craigslist.org/00F0F_2yGuBZm8e4Z_600x450.jpg
# 00F0F_2yGuBZm8e4Z_600x450.jpg
# https://images.craigslist.org/00505_7FidekSoTK8_600x450.jpg
# 00505_7FidekSoTK8_600x450.jpg
# https://images.craigslist.org/00Z0Z_eXYs4AumUAS_600x450.jpg
# 00Z0Z_eXYs4AumUAS_600x450.jpg
# https://images.craigslist.org/01010_2nY3u5on4Ho_600x450.jpg
# 01010_2nY3u5on4Ho_600x450.jpg
# https://images.craigslist.org/00101_fPwn9kqyd0r_600x450.jpg
# 00101_fPwn9kqyd0r_600x450.jpg
# https://images.craigslist.org/00707_42kULgH4Nbm_600x450.jpg
# 00707_42kULgH4Nbm_600x450.jpg
# https://images.craigslist.org/00i0i_4MyLHaCwQFB_600x450.jpg
# 00i0i_4MyLHaCwQFB_600x450.jpg
# https://images.craigslist.org/00C0C_d763HAj8nxH_600x450.jpg
# 00C0C_d763HAj8nxH_600x450.jpg
# https://images.craigslist.org/00k0k_eXY3uwbsya_600x450.jpg
# 00k0k_eXY3uwbsya_600x450.jpg
# https://images.craigslist.org/00W0W_37rdjXb6avT_600x450.jpg
# 00W0W_37rdjXb6avT_600x450.jpg
# https://images.craigslist.org/00303_3WYTc0bkxkq_600x450.jpg
# 00303_3WYTc0bkxkq_600x450.jpg
# https://images.craigslist.org/01515_iZYKNAIzhTH_600x450.jpg
# 01515_iZYKNAIzhTH_600x450.jpg
# https://images.craigslist.org/00f0f_1GLJtTLEhKu_600x450.jpg
# 00f0f_1GLJtTLEhKu_600x450.jpg
# https://images.craigslist.org/00h0h_hfDLP8jPZOs_600x450.jpg
# 00h0h_hfDLP8jPZOs_600x450.jpg
# https://images.craigslist.org/00y0y_grGQfUE29FW_600x450.jpg
# 00y0y_grGQfUE29FW_600x450.jpg
# https://images.craigslist.org/00H0H_9niF6GCZg6Z_600x450.jpg
# 00H0H_9niF6GCZg6Z_600x450.jpg
# https://images.craigslist.org/01515_k8Gznwt6Oxn_600x450.jpg
# 01515_k8Gznwt6Oxn_600x450.jpg
# https://images.craigslist.org/00g0g_3UurbAfi3Dt_600x450.jpg
# 00g0g_3UurbAfi3Dt_600x450.jpg
# https://images.craigslist.org/00n0n_cMAk96frP2y_600x450.jpg
# 00n0n_cMAk96frP2y_600x450.jpg
# https://images.craigslist.org/00404_gR73cwdmOvn_600x450.jpg
# 00404_gR73cwdmOvn_600x450.jpg
# https://images.craigslist.org/00F0F_3VRsnGLYXsJ_600x450.jpg
# 00F0F_3VRsnGLYXsJ_600x450.jpg
# https://images.craigslist.org/01212_89gBBIZ1vCD_600x450.jpg
# 01212_89gBBIZ1vCD_600x450.jpg
# https://images.craigslist.org/00i0i_kWJStA00Lfu_600x450.jpg
# 00i0i_kWJStA00Lfu_600x450.jpg
# https://images.craigslist.org/00606_8BBJRIePdAc_600x450.jpg
# 00606_8BBJRIePdAc_600x450.jpg
# https://images.craigslist.org/00R0R_3JSNlmFVbUu_600x450.jpg
# 00R0R_3JSNlmFVbUu_600x450.jpg
# https://images.craigslist.org/01313_7k1wogZhtbY_600x450.jpg
# 01313_7k1wogZhtbY_600x450.jpg
# https://images.craigslist.org/00G0G_bzTZwFt6ZO3_600x450.jpg
# 00G0G_bzTZwFt6ZO3_600x450.jpg
